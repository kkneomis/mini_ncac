# %% [markdown]
# ## Mini NCAC Challenge
#
# This is condensed version of the NCAC challenge. It should take a little less than 3 hours to complete as opposed to 50 hours. Thus, a lot of the data will be reducted and hints/pointers will be given.

# %% [markdown]
# ### Instructions / Indicators
#
# The FBI called to inform you they noticed traffic from your company to a known bad APT drop site. Details were sketchy and sparse as usual; however, the FBI indicated that it observed a file “d.7z” being transferred. No analysis of the contents of the file was conducted (or they didn’t care to share).
#
# Although there is no evidence the attackers used email as a delivery vector, the FBI indicated this particular adversary regularly uses career-type themes to target job seekers and HR personnel. Previously observed email Subjects were:
#
# “Your CV has been updated”
# “Take career to your level next”
# “Tried of grind”
# “opportunity waits”
#
# No other information is available at this time.

# %% [markdown]
# ### Question 1
#
# **Q: The file "d.7z" was retrieved from this external IP address.**
# A: 203.57.206.173
# Hint: Grep for the file name in firewall.log
#
#
# ### Question 2
#
# **Q: In addition to d.7z these three other zip files were stored to an external source at about the same time**
# A: "7.za", "a.7z", and "b.7z"
# Hint: Grep for 203.57.206.173 in firewall.log. Eyeball the results
#
# ### Question 3
#
# **Q: This exe file was retrieved from the same IP address **
# A: "7za.exe"
# Hint: Grep for 203.57.206.173 in firewall.log. Eyeball the results
#
#
# ### Question 4
#
# **Q: A user downloaded an executable while browsing a career themed watering hole with related to the malicious IP. The domain of that website is:**
# A: jobs.securityintelligence[.]com
# Hint: Grep for 203.57.206.173 accross all the Border device logs. The answer should be in the squid_proxy
#
# ### Question 5
#
# **Q: The name of the malicious executable is**
# A: d11host.exe
# Hint: Same as above
#
# ### Question 6
#
# **Q: This external IP address is also associated with the domain mentioned above**
# A: 60.235.12.64
# Hint: Grep for the domain in the squid proxy. Eyeball the results.
#
#
# ### Question 7
#
# **Q: The hash of the file is**
# A: 760bd1c3c3202a496d869d5e6c0b5cca
# Hint:
# * Open 203.57.206.173.pcap in wireshare. Filter on  'tcp contains "d11host.exe"'.
# * Follow the stream (Analyze > Follow> TCP Stream).
# * Make sure the select only the http response.
# * Save the **raw** data d11host.exe. You will need to remove the http response header (can be done in vim).
# * Use the md5 command on the file to get the hash.
# * Additonal hint: Since it is an exe file, the first two bytes should be [4d 5a] or "MZ"
#
#
# ### Question 8
#
# **Q: The executable is a strain of this Remote Access Tool**
# A: PoisonIvy
# Hint: Look up the hash in virustotal. You could also feed the file to VT, but I already did it for you.
# Note: for real world APT, you probably don't want to do that immediately.
# https://www.virustotal.com/gui/file/2243ea1b3260e765049074241f19df4b1871d9342a3b60cc7f8594b29c6b7dac/behavior/VirusTotal%20Cuckoofork
#
#
# ### Question 9
#
# **Q: The user also downloaded two script that would automate ftp tasks. The scripts are named name ___.txt**
# A: ftp_helo.txt, ftp_bye.txt
# Hint: This requires one grep command piped into another.
# Mine was: ```grep -r securityintelligence.com  . | grep txt | less```
# Note the 404 response code on ftb_helo.txt
#
#
# ### Question 10
#
# **Q: The adversary IP Address 60.235.12.64, performed some reconnaissance on SICCO INC before the attack. Based on the blog ____ is the leading APT detection software developed by SICCO, Inc:**
# A: Vortex
# Hint:
# * Go back to the conviniently supplied 60.235.12.64.pcap
# * Filter on the org's domain: "siccoinc.com" -- ```tcp contains "siccoinc.com"```
# * Look for the Get request to blog.html
# * Follow the stream
# * Read the page content, ignore the html
#
# ### Question 11
#
# **Q: Sicco Inc. launched a partnership with this company in order to develop the Vortex product.**
# A: Illusory Inc.
# Hint: Same as above. Just read carefully.
#
# ### Question 12
#
# **Q: The president & owner of that company is named**
# A: Dirk Diggler
# Hint: The information isn't contained on Sicco Inc's website. You will need to look in the mail traffic (mail.pcap).
# * You can filter on ```tcp contains "Illusory" and tcp contains "President"```
# * You will need to read past the first few emails
#
#
#
# ### Question 13
#
# **Q: Several Sicco Inc employees received an email atttachment which Diggler claims he never sent. The name of that attachment is:**
# A: 2012_Incentive_Plan.pdf
# Hint: From the last question we know that Dirk Diggler's email address is "dirkdiggler853@gmail.com". We can filter on that email adress and read through the conversations. The confusions is detailed in an email thread with  Jules Winnfield. This tasks is easier done using ngrep.
#
#
# ### Question 14
#
# **Q: There were 4 recipients to the mysterious attachments. Their email addresses are:**
# A: jules.winnfield@siccoinc.com, martin.bishop@siccoinc.com, marsellus.wallace@siccoinc.com, vincent.vega@siccoinc.com
# Hint: In wireshark, filter on "2012_Incentive_Plan.pdf". Follow the four streams.
#
# ### Question 15
#
# **Q: A legitimate email from Dirk Diggler (dirkdiggler853) would normally come from this email server**
# A: mail-qy0-f172.google.com
# Hint: The email thread with Jules Winnfield sounds like the real guy. Look at the email headers.
#
# ### Question 16
#
# **Q: The spoofed message from Diggler came from this mail server**
# A: nm3.bullet.mail.tp2.yahoo.com
# Hint: The email containing only the pdf attachment and a vague message sounds spoofeed. Check the email headers.
#
# ### Question 17
#
# **Q: The attachment in encoded in:**
# A: base64
# Hint: A quick google search reveals the answer.
# * If you can't find it, look here:  https://www.cisco.com/c/en/us/support/docs/security/email-security-appliance/118499-qa-esa-00.html
#
# ### Question 18
#
# **Q: The pdf says:**
# A: Hello World!
# Hint: You will need to carve the file out of the email.
# * Copy and paste the base64 data into a file (ex: attachment.b64)
# * Base64 decode the data and write it to a new file. Ex: ```base64 -d attachment.b64 >> 2012_Incentive_Plan.pdf```
# * Open the file
#
# ### Question 19
#
# **Q: The hash of the file is:**
# A: f9ecc22aabe9fce7ed2a542f21b53ea8
# Hint: Use the md5 command
#
# ### Question 20
#
# **Q: This employee actually downloaded the pdf attachment**
# A: Vincent Vega
# Hint: If a user actuallly downloaded the file (if it is written on disk), it should show up in their Master File Table (conviniently supplied).
# * In the MFT folder, grep for the file name ```grep -r 2012_Incentive_Plan.pdf . | less```
# * It only shows up on client07, which is allocated to Vincent Vega
#
# ### Question 21
#
# **Q: The adversary (203.57.206.173) downloaded a series tools on this user's machine**
# A: Darren Roskow
# Hint: This going back to the initial thread. Open 203.57.206.173.pcap and filter on port 443. Follow any of the streams and you should get a pretty thorough list of what the adversary is doing.
#
# ### Question 22
#
# **Q: The adversary's tools were stored in this folder:  C:\Windows\____\ **
# A: WBEM
# Hint: Same as above, just read carefully.
#
# ### Question 23
#
# **Q: During the Adversary's command and control sessions, they used this Helpdesk password to run the psexec process **
# A: H3lp0M3!!
# Hint: Same as above.
#
# ### Question 24
#
# **Q: The adversary dumps system/user passwords in this file:**
# A: 10.10.53.2.pwdump
# Hint:
#
# ### Question 25
#
# **Q: The adversary exfiltrated this employee's emails by first consolidating them in a file called _____.pst**
# A: "My Outlook Data File.pst"
# Hint:
#
# ### Question 26
#
# **Q: The employee in questions is:**
# A: Martin Bishop
# Hint:
